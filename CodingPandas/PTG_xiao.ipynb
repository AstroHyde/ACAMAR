# %%
import sys
import matplotlib
import matplotlib.path as mpath
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure, show, axis
from matplotlib.patches import Ellipse
import scipy
import numpy as np
from numpy import *
import math
import pylab
import random
from pylab import *
from astropy.coordinates import SkyCoord
from astropy import units as u
import pylab as P
from astropy.io import ascii
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans, k_means
from sklearn.metrics import silhouette_score
from sklearn.datasets.samples_generator import make_blobs
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso, LassoCV
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from scipy.optimize import curve_fit

matplotlib.style.use('ggplot')

sns.set_style('darkgrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
dat4=ascii.read("Leo4_lisp_rod_sdss_ppmxl")#,data_start=2)
dat5=ascii.read("Leo5_lisp_rod_sdss_ppmxl")#,data_start=2)
datB=ascii.read("LeoB_lisp_rod_sdss_ppmxl")#,data_start=2)

# %%
vhc4 = dat4['Vhel']
verr4 = dat4['Verr']
vhc5 = dat5['Vhel']
verr5 = dat5['Verr']
vhcB = datB['Vhel']
verrB = datB['Verr']

Radeg4=dat4['RA']
Decdeg4=dat4['DEC']
Radeg5=dat5['RA']
Decdeg5=dat5['DEC']
RadegB=datB['RA']
DecdegB=datB['DEC']

alphaFe4=dat4['alphaFe']
mH4=dat4['mH']
alphaFe5=dat5['alphaFe']
mH5=dat5['mH']
alphaFeB=datB['alphaFe']
mHB=datB['mH']

vrot4=dat4['Vrot']
vrot5=dat5['Vrot']
vrotB=datB['Vrot']

Teff4=dat4['Teff']
Teff5=dat5['Teff']
TeffB=datB['Teff']

Logg4=dat4['Logg']
Logg5=dat5['Logg']
LoggB=datB['Logg']

# %%
#test section
meta4=alphaFe4/mH4
meta5=alphaFe5/mH5
metaB=alphaFeB/mHB
#print(alphaFe4[0],alphaFe4[1],alphaFe4[2])
#print(mH4[0],mH4[1],mH4[2])
#print(meta4[0],meta4[1],meta4[2])
#def func(x,k,b):
#    y=k*x+b
#    return y

#popt4,pcov4=curve_fit(func,Teff4,vrot4)
#popt5,pcov5=curve_fit(func,Teff5,vrot5)
#poptB,pcovB=curve_fit(func,TeffB,vrotB)

# %%
fig0=plt.figure(1)
ax=fig0.add_subplot(111)
#ax.plot(Teff4,Logg4,'*r',label='Leo4',zorder=-1)
#ax.plot(Teff5,Logg5,'*g',label='Leo5',zorder=-1)
#ax.plot(TeffB,LoggB,'*b',label='Leo4.5',zorder=-1)
ax.plot(mH4,vrot4,'*r',label='Leo4',zorder=-1)
ax.plot(mH5,vrot5,'*g',label='Leo5',zorder=-1)
ax.plot(mHB,vrotB,'*b',label='Leo4.5',zorder=-1)
#ax.plot(Teff4,func(Teff4,popt4[0],popt4[1]))
#ax.plot(Teff5,func(Teff5,popt5[0],popt5[1]))
#ax.plot(TeffB,func(TeffB,poptB[0],poptB[1]))
ax.axhline(220,-10,10)
#ax.set_xlim([-2,2])
#ax.set_ylim([0,600])
ax.set_xlabel(r'$\mathrm{metal}$',fontsize=18)
ax.set_ylabel(r'$\mathrm{vrot}$',fontsize=18)
#ax.legend(markerscale=(2), loc=1, numpoints=1)
plt.show()
